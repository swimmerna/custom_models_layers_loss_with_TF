# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 272.9725 - y1_output_loss: 123.5770 - y2_output_loss: 147.0774 - y1_output_root_mean_squared_error: 11.1667 - y2_output_root_mean_squared_error: 12.1769 - val_loss: 40.7657 - val_y1_output_loss: 18.7242 - val_y2_output_loss: 22.8736 - val_y1_output_root_mean_squared_error: 4.2967 - val_y2_output_root_mean_squared_error: 4.7227
# Epoch 2/500
# 614/614 [==============================] - 0s 157us/sample - loss: 30.8570 - y1_output_loss: 12.5848 - y2_output_loss: 18.6274 - y1_output_root_mean_squared_error: 3.5327 - y2_output_root_mean_squared_error: 4.2869 - val_loss: 32.3291 - val_y1_output_loss: 11.1456 - val_y2_output_loss: 20.1848 - val_y1_output_root_mean_squared_error: 3.3993 - val_y2_output_root_mean_squared_error: 4.5578
# Epoch 3/500
# 614/614 [==============================] - 0s 146us/sample - loss: 30.1023 - y1_output_loss: 10.7039 - y2_output_loss: 19.1764 - y1_output_root_mean_squared_error: 3.2861 - y2_output_root_mean_squared_error: 4.3936 - val_loss: 23.5192 - val_y1_output_loss: 10.0180 - val_y2_output_loss: 13.8786 - val_y1_output_root_mean_squared_error: 3.1799 - val_y2_output_root_mean_squared_error: 3.6616
# Epoch 4/500
# 614/614 [==============================] - 0s 148us/sample - loss: 25.2980 - y1_output_loss: 9.4334 - y2_output_loss: 15.7397 - y1_output_root_mean_squared_error: 3.0805 - y2_output_root_mean_squared_error: 3.9760 - val_loss: 23.6167 - val_y1_output_loss: 11.6164 - val_y2_output_loss: 11.7610 - val_y1_output_root_mean_squared_error: 3.4355 - val_y2_output_root_mean_squared_error: 3.4372
# Epoch 5/500
# 614/614 [==============================] - 0s 146us/sample - loss: 22.8394 - y1_output_loss: 8.8332 - y2_output_loss: 13.9886 - y1_output_root_mean_squared_error: 2.9759 - y2_output_root_mean_squared_error: 3.7394 - val_loss: 32.5440 - val_y1_output_loss: 12.2975 - val_y2_output_loss: 19.4366 - val_y1_output_root_mean_squared_error: 3.5585 - val_y2_output_root_mean_squared_error: 4.4588
# Epoch 6/500
# 614/614 [==============================] - 0s 147us/sample - loss: 22.0193 - y1_output_loss: 8.7768 - y2_output_loss: 13.3198 - y1_output_root_mean_squared_error: 2.9475 - y2_output_root_mean_squared_error: 3.6512 - val_loss: 23.0765 - val_y1_output_loss: 9.1800 - val_y2_output_loss: 13.5306 - val_y1_output_root_mean_squared_error: 3.0559 - val_y2_output_root_mean_squared_error: 3.7065
# Epoch 7/500
# 614/614 [==============================] - 0s 159us/sample - loss: 21.6667 - y1_output_loss: 8.7168 - y2_output_loss: 12.8921 - y1_output_root_mean_squared_error: 2.9502 - y2_output_root_mean_squared_error: 3.6004 - val_loss: 41.0816 - val_y1_output_loss: 12.8900 - val_y2_output_loss: 27.7055 - val_y1_output_root_mean_squared_error: 3.6161 - val_y2_output_root_mean_squared_error: 5.2920
# Epoch 8/500
# 614/614 [==============================] - 0s 148us/sample - loss: 25.2562 - y1_output_loss: 9.2325 - y2_output_loss: 16.2634 - y1_output_root_mean_squared_error: 3.0099 - y2_output_root_mean_squared_error: 4.0245 - val_loss: 61.7815 - val_y1_output_loss: 17.6562 - val_y2_output_loss: 43.1636 - val_y1_output_root_mean_squared_error: 4.2456 - val_y2_output_root_mean_squared_error: 6.6148
# Epoch 9/500
# 614/614 [==============================] - 0s 144us/sample - loss: 23.1793 - y1_output_loss: 8.8063 - y2_output_loss: 14.3574 - y1_output_root_mean_squared_error: 2.9707 - y2_output_root_mean_squared_error: 3.7887 - val_loss: 19.1548 - val_y1_output_loss: 9.1820 - val_y2_output_loss: 9.7943 - val_y1_output_root_mean_squared_error: 3.0585 - val_y2_output_root_mean_squared_error: 3.1305
# Epoch 10/500
# 614/614 [==============================] - 0s 144us/sample - loss: 22.1622 - y1_output_loss: 7.9352 - y2_output_loss: 14.0310 - y1_output_root_mean_squared_error: 2.8286 - y2_output_root_mean_squared_error: 3.7631 - val_loss: 21.5937 - val_y1_output_loss: 9.4311 - val_y2_output_loss: 11.7355 - val_y1_output_root_mean_squared_error: 3.1051 - val_y2_output_root_mean_squared_error: 3.4572
# Epoch 11/500
# 614/614 [==============================] - 0s 142us/sample - loss: 20.6070 - y1_output_loss: 7.9455 - y2_output_loss: 12.5347 - y1_output_root_mean_squared_error: 2.8281 - y2_output_root_mean_squared_error: 3.5509 - val_loss: 17.0746 - val_y1_output_loss: 8.3013 - val_y2_output_loss: 8.6442 - val_y1_output_root_mean_squared_error: 2.9088 - val_y2_output_root_mean_squared_error: 2.9348
# Epoch 12/500
# 614/614 [==============================] - 0s 145us/sample - loss: 25.3672 - y1_output_loss: 8.4525 - y2_output_loss: 16.7379 - y1_output_root_mean_squared_error: 2.9165 - y2_output_root_mean_squared_error: 4.1062 - val_loss: 15.6081 - val_y1_output_loss: 7.7325 - val_y2_output_loss: 7.8453 - val_y1_output_root_mean_squared_error: 2.8013 - val_y2_output_root_mean_squared_error: 2.7859
# Epoch 13/500
# 614/614 [==============================] - 0s 193us/sample - loss: 21.3779 - y1_output_loss: 7.6783 - y2_output_loss: 13.5066 - y1_output_root_mean_squared_error: 2.7839 - y2_output_root_mean_squared_error: 3.6916 - val_loss: 14.6359 - val_y1_output_loss: 7.3174 - val_y2_output_loss: 7.4670 - val_y1_output_root_mean_squared_error: 2.7065 - val_y2_output_root_mean_squared_error: 2.7039
# Epoch 14/500
# 614/614 [==============================] - 0s 144us/sample - loss: 18.3284 - y1_output_loss: 6.9964 - y2_output_loss: 11.2825 - y1_output_root_mean_squared_error: 2.6372 - y2_output_root_mean_squared_error: 3.3725 - val_loss: 18.5308 - val_y1_output_loss: 9.2740 - val_y2_output_loss: 9.8196 - val_y1_output_root_mean_squared_error: 3.0285 - val_y2_output_root_mean_squared_error: 3.0593
# Epoch 15/500
# 614/614 [==============================] - 0s 149us/sample - loss: 18.8548 - y1_output_loss: 7.3339 - y2_output_loss: 11.6883 - y1_output_root_mean_squared_error: 2.6881 - y2_output_root_mean_squared_error: 3.4101 - val_loss: 24.1598 - val_y1_output_loss: 8.1123 - val_y2_output_loss: 15.4393 - val_y1_output_root_mean_squared_error: 2.8912 - val_y2_output_root_mean_squared_error: 3.9750
# Epoch 16/500
# 614/614 [==============================] - 0s 147us/sample - loss: 17.2292 - y1_output_loss: 6.4556 - y2_output_loss: 10.6366 - y1_output_root_mean_squared_error: 2.5519 - y2_output_root_mean_squared_error: 3.2737 - val_loss: 12.8296 - val_y1_output_loss: 6.5295 - val_y2_output_loss: 6.5381 - val_y1_output_root_mean_squared_error: 2.5546 - val_y2_output_root_mean_squared_error: 2.5107
# Epoch 17/500
# 614/614 [==============================] - 0s 146us/sample - loss: 15.8937 - y1_output_loss: 5.8820 - y2_output_loss: 9.9850 - y1_output_root_mean_squared_error: 2.4296 - y2_output_root_mean_squared_error: 3.1608 - val_loss: 14.4936 - val_y1_output_loss: 6.6484 - val_y2_output_loss: 8.5259 - val_y1_output_root_mean_squared_error: 2.5596 - val_y2_output_root_mean_squared_error: 2.8182
# Epoch 18/500
# 614/614 [==============================] - 0s 148us/sample - loss: 16.3841 - y1_output_loss: 5.8979 - y2_output_loss: 10.3847 - y1_output_root_mean_squared_error: 2.4355 - y2_output_root_mean_squared_error: 3.2330 - val_loss: 14.0226 - val_y1_output_loss: 6.8606 - val_y2_output_loss: 7.5897 - val_y1_output_root_mean_squared_error: 2.6056 - val_y2_output_root_mean_squared_error: 2.6895
# Epoch 19/500
# 614/614 [==============================] - 0s 149us/sample - loss: 18.5505 - y1_output_loss: 6.5705 - y2_output_loss: 12.1118 - y1_output_root_mean_squared_error: 2.5657 - y2_output_root_mean_squared_error: 3.4594 - val_loss: 85.4062 - val_y1_output_loss: 18.7831 - val_y2_output_loss: 67.5490 - val_y1_output_root_mean_squared_error: 4.3331 - val_y2_output_root_mean_squared_error: 8.1627
# Epoch 20/500
# 614/614 [==============================] - 0s 148us/sample - loss: 20.0803 - y1_output_loss: 6.6674 - y2_output_loss: 13.4353 - y1_output_root_mean_squared_error: 2.5816 - y2_output_root_mean_squared_error: 3.6627 - val_loss: 26.1995 - val_y1_output_loss: 8.3468 - val_y2_output_loss: 17.5627 - val_y1_output_root_mean_squared_error: 2.9044 - val_y2_output_root_mean_squared_error: 4.2147
# Epoch 21/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.9122 - y1_output_loss: 5.1488 - y2_output_loss: 8.6222 - y1_output_root_mean_squared_error: 2.2074 - y2_output_root_mean_squared_error: 2.8354 - val_loss: 164.3387 - val_y1_output_loss: 47.1752 - val_y2_output_loss: 116.5580 - val_y1_output_root_mean_squared_error: 6.8741 - val_y2_output_root_mean_squared_error: 10.8206
# Epoch 22/500
# 614/614 [==============================] - 0s 149us/sample - loss: 17.6886 - y1_output_loss: 6.3360 - y2_output_loss: 11.3377 - y1_output_root_mean_squared_error: 2.5245 - y2_output_root_mean_squared_error: 3.3639 - val_loss: 40.8485 - val_y1_output_loss: 8.9437 - val_y2_output_loss: 33.2511 - val_y1_output_root_mean_squared_error: 2.9588 - val_y2_output_root_mean_squared_error: 5.6652
# Epoch 23/500
# 614/614 [==============================] - 0s 145us/sample - loss: 13.3379 - y1_output_loss: 5.3260 - y2_output_loss: 7.8965 - y1_output_root_mean_squared_error: 2.3176 - y2_output_root_mean_squared_error: 2.8225 - val_loss: 11.1257 - val_y1_output_loss: 4.8163 - val_y2_output_loss: 6.2999 - val_y1_output_root_mean_squared_error: 2.2043 - val_y2_output_root_mean_squared_error: 2.5034
# Epoch 24/500
# 614/614 [==============================] - 0s 152us/sample - loss: 15.1505 - y1_output_loss: 5.2256 - y2_output_loss: 9.8560 - y1_output_root_mean_squared_error: 2.2857 - y2_output_root_mean_squared_error: 3.1506 - val_loss: 10.8652 - val_y1_output_loss: 5.3450 - val_y2_output_loss: 5.6286 - val_y1_output_root_mean_squared_error: 2.3234 - val_y2_output_root_mean_squared_error: 2.3382
# Epoch 25/500
# 614/614 [==============================] - 0s 146us/sample - loss: 14.5988 - y1_output_loss: 5.2130 - y2_output_loss: 9.2488 - y1_output_root_mean_squared_error: 2.2938 - y2_output_root_mean_squared_error: 3.0557 - val_loss: 10.7736 - val_y1_output_loss: 5.2569 - val_y2_output_loss: 5.4645 - val_y1_output_root_mean_squared_error: 2.3158 - val_y2_output_root_mean_squared_error: 2.3261
# Epoch 26/500
# 614/614 [==============================] - 0s 176us/sample - loss: 14.4290 - y1_output_loss: 4.8310 - y2_output_loss: 9.6039 - y1_output_root_mean_squared_error: 2.2055 - y2_output_root_mean_squared_error: 3.0927 - val_loss: 17.3111 - val_y1_output_loss: 5.1871 - val_y2_output_loss: 12.7847 - val_y1_output_root_mean_squared_error: 2.2588 - val_y2_output_root_mean_squared_error: 3.4941
# Epoch 27/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.6203 - y1_output_loss: 4.6152 - y2_output_loss: 8.1514 - y1_output_root_mean_squared_error: 2.1401 - y2_output_root_mean_squared_error: 2.8356 - val_loss: 10.7469 - val_y1_output_loss: 4.3967 - val_y2_output_loss: 6.4535 - val_y1_output_root_mean_squared_error: 2.1154 - val_y2_output_root_mean_squared_error: 2.5044
# Epoch 28/500
# 614/614 [==============================] - 0s 145us/sample - loss: 10.7867 - y1_output_loss: 4.0819 - y2_output_loss: 6.6795 - y1_output_root_mean_squared_error: 2.0149 - y2_output_root_mean_squared_error: 2.5937 - val_loss: 19.4323 - val_y1_output_loss: 8.2987 - val_y2_output_loss: 10.7190 - val_y1_output_root_mean_squared_error: 2.9154 - val_y2_output_root_mean_squared_error: 3.3065
# Epoch 29/500
# 614/614 [==============================] - 0s 143us/sample - loss: 11.2833 - y1_output_loss: 3.8767 - y2_output_loss: 7.3673 - y1_output_root_mean_squared_error: 1.9654 - y2_output_root_mean_squared_error: 2.7241 - val_loss: 22.0683 - val_y1_output_loss: 8.0352 - val_y2_output_loss: 13.7197 - val_y1_output_root_mean_squared_error: 2.8581 - val_y2_output_root_mean_squared_error: 3.7282
# Epoch 30/500
# 614/614 [==============================] - 0s 149us/sample - loss: 10.5751 - y1_output_loss: 3.6253 - y2_output_loss: 6.8699 - y1_output_root_mean_squared_error: 1.9093 - y2_output_root_mean_squared_error: 2.6325 - val_loss: 10.6614 - val_y1_output_loss: 4.9342 - val_y2_output_loss: 5.8665 - val_y1_output_root_mean_squared_error: 2.2265 - val_y2_output_root_mean_squared_error: 2.3883
# Epoch 31/500
# 614/614 [==============================] - 0s 147us/sample - loss: 11.1286 - y1_output_loss: 3.9595 - y2_output_loss: 7.1095 - y1_output_root_mean_squared_error: 1.9942 - y2_output_root_mean_squared_error: 2.6743 - val_loss: 11.6205 - val_y1_output_loss: 4.2679 - val_y2_output_loss: 7.1847 - val_y1_output_root_mean_squared_error: 2.0859 - val_y2_output_root_mean_squared_error: 2.6962
# Epoch 32/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.2419 - y1_output_loss: 3.4060 - y2_output_loss: 6.7749 - y1_output_root_mean_squared_error: 1.8503 - y2_output_root_mean_squared_error: 2.6112 - val_loss: 9.5091 - val_y1_output_loss: 3.4058 - val_y2_output_loss: 6.1434 - val_y1_output_root_mean_squared_error: 1.8320 - val_y2_output_root_mean_squared_error: 2.4805
# Epoch 33/500
# 614/614 [==============================] - 0s 150us/sample - loss: 10.0946 - y1_output_loss: 3.3246 - y2_output_loss: 6.7140 - y1_output_root_mean_squared_error: 1.8264 - y2_output_root_mean_squared_error: 2.5998 - val_loss: 15.2067 - val_y1_output_loss: 5.0370 - val_y2_output_loss: 9.9192 - val_y1_output_root_mean_squared_error: 2.2673 - val_y2_output_root_mean_squared_error: 3.1727
# Epoch 34/500
# 614/614 [==============================] - 0s 150us/sample - loss: 10.5009 - y1_output_loss: 3.6116 - y2_output_loss: 6.9064 - y1_output_root_mean_squared_error: 1.8980 - y2_output_root_mean_squared_error: 2.6265 - val_loss: 18.2567 - val_y1_output_loss: 6.4461 - val_y2_output_loss: 12.5861 - val_y1_output_root_mean_squared_error: 2.5048 - val_y2_output_root_mean_squared_error: 3.4616
# Epoch 35/500
# 614/614 [==============================] - 0s 154us/sample - loss: 9.3010 - y1_output_loss: 3.1971 - y2_output_loss: 6.0405 - y1_output_root_mean_squared_error: 1.7957 - y2_output_root_mean_squared_error: 2.4650 - val_loss: 8.1762 - val_y1_output_loss: 3.3394 - val_y2_output_loss: 5.0657 - val_y1_output_root_mean_squared_error: 1.8250 - val_y2_output_root_mean_squared_error: 2.2013
# Epoch 36/500
# 614/614 [==============================] - 0s 152us/sample - loss: 10.5336 - y1_output_loss: 3.5018 - y2_output_loss: 7.0168 - y1_output_root_mean_squared_error: 1.8739 - y2_output_root_mean_squared_error: 2.6500 - val_loss: 10.8819 - val_y1_output_loss: 3.2890 - val_y2_output_loss: 7.4418 - val_y1_output_root_mean_squared_error: 1.8197 - val_y2_output_root_mean_squared_error: 2.7514
# Epoch 37/500
# 614/614 [==============================] - 0s 145us/sample - loss: 9.1520 - y1_output_loss: 2.9352 - y2_output_loss: 6.2421 - y1_output_root_mean_squared_error: 1.6997 - y2_output_root_mean_squared_error: 2.5026 - val_loss: 21.9520 - val_y1_output_loss: 6.1495 - val_y2_output_loss: 15.4046 - val_y1_output_root_mean_squared_error: 2.5066 - val_y2_output_root_mean_squared_error: 3.9584
# Epoch 38/500
# 614/614 [==============================] - 0s 145us/sample - loss: 9.7595 - y1_output_loss: 3.0502 - y2_output_loss: 6.6995 - y1_output_root_mean_squared_error: 1.7522 - y2_output_root_mean_squared_error: 2.5864 - val_loss: 13.0070 - val_y1_output_loss: 2.9501 - val_y2_output_loss: 9.8314 - val_y1_output_root_mean_squared_error: 1.7292 - val_y2_output_root_mean_squared_error: 3.1650
# Epoch 39/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.3268 - y1_output_loss: 2.7166 - y2_output_loss: 5.7541 - y1_output_root_mean_squared_error: 1.6312 - y2_output_root_mean_squared_error: 2.3803 - val_loss: 29.1670 - val_y1_output_loss: 9.7404 - val_y2_output_loss: 18.6209 - val_y1_output_root_mean_squared_error: 3.1708 - val_y2_output_root_mean_squared_error: 4.3718
# Epoch 40/500
# 614/614 [==============================] - 0s 154us/sample - loss: 8.5505 - y1_output_loss: 2.8401 - y2_output_loss: 5.7781 - y1_output_root_mean_squared_error: 1.6522 - y2_output_root_mean_squared_error: 2.4126 - val_loss: 11.1418 - val_y1_output_loss: 6.0673 - val_y2_output_loss: 5.7361 - val_y1_output_root_mean_squared_error: 2.4008 - val_y2_output_root_mean_squared_error: 2.3190
# Epoch 41/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.1353 - y1_output_loss: 2.9577 - y2_output_loss: 7.1025 - y1_output_root_mean_squared_error: 1.7219 - y2_output_root_mean_squared_error: 2.6778 - val_loss: 7.6447 - val_y1_output_loss: 3.1609 - val_y2_output_loss: 4.7496 - val_y1_output_root_mean_squared_error: 1.7636 - val_y2_output_root_mean_squared_error: 2.1294
# Epoch 42/500
# 614/614 [==============================] - 0s 205us/sample - loss: 8.0285 - y1_output_loss: 2.6418 - y2_output_loss: 5.3705 - y1_output_root_mean_squared_error: 1.6285 - y2_output_root_mean_squared_error: 2.3187 - val_loss: 10.6725 - val_y1_output_loss: 3.7861 - val_y2_output_loss: 7.5359 - val_y1_output_root_mean_squared_error: 1.9103 - val_y2_output_root_mean_squared_error: 2.6502
# Epoch 43/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.3403 - y1_output_loss: 2.6090 - y2_output_loss: 5.8178 - y1_output_root_mean_squared_error: 1.6162 - y2_output_root_mean_squared_error: 2.3934 - val_loss: 39.1993 - val_y1_output_loss: 12.9646 - val_y2_output_loss: 27.0073 - val_y1_output_root_mean_squared_error: 3.5781 - val_y2_output_root_mean_squared_error: 5.1378
# Epoch 44/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.2086 - y1_output_loss: 3.1743 - y2_output_loss: 7.0063 - y1_output_root_mean_squared_error: 1.7850 - y2_output_root_mean_squared_error: 2.6500 - val_loss: 8.2703 - val_y1_output_loss: 3.6097 - val_y2_output_loss: 5.0654 - val_y1_output_root_mean_squared_error: 1.8661 - val_y2_output_root_mean_squared_error: 2.1882
# Epoch 45/500
# 614/614 [==============================] - 0s 138us/sample - loss: 9.0269 - y1_output_loss: 2.9273 - y2_output_loss: 6.1732 - y1_output_root_mean_squared_error: 1.7023 - y2_output_root_mean_squared_error: 2.4757 - val_loss: 10.3905 - val_y1_output_loss: 3.1367 - val_y2_output_loss: 6.9651 - val_y1_output_root_mean_squared_error: 1.8004 - val_y2_output_root_mean_squared_error: 2.6738
# Epoch 46/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.5327 - y1_output_loss: 2.6084 - y2_output_loss: 5.8444 - y1_output_root_mean_squared_error: 1.6224 - y2_output_root_mean_squared_error: 2.4291 - val_loss: 6.5109 - val_y1_output_loss: 2.4991 - val_y2_output_loss: 3.9163 - val_y1_output_root_mean_squared_error: 1.6004 - val_y2_output_root_mean_squared_error: 1.9874
# Epoch 47/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.7944 - y1_output_loss: 2.7175 - y2_output_loss: 6.1993 - y1_output_root_mean_squared_error: 1.6336 - y2_output_root_mean_squared_error: 2.4750 - val_loss: 19.0584 - val_y1_output_loss: 6.1446 - val_y2_output_loss: 12.4431 - val_y1_output_root_mean_squared_error: 2.5138 - val_y2_output_root_mean_squared_error: 3.5692
# Epoch 48/500
# 614/614 [==============================] - 0s 159us/sample - loss: 7.7134 - y1_output_loss: 2.3630 - y2_output_loss: 5.3055 - y1_output_root_mean_squared_error: 1.5392 - y2_output_root_mean_squared_error: 2.3118 - val_loss: 6.9662 - val_y1_output_loss: 2.5090 - val_y2_output_loss: 4.4129 - val_y1_output_root_mean_squared_error: 1.5895 - val_y2_output_root_mean_squared_error: 2.1071
# Epoch 49/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.6659 - y1_output_loss: 2.2803 - y2_output_loss: 5.3671 - y1_output_root_mean_squared_error: 1.5149 - y2_output_root_mean_squared_error: 2.3176 - val_loss: 6.6362 - val_y1_output_loss: 2.5597 - val_y2_output_loss: 4.3367 - val_y1_output_root_mean_squared_error: 1.5882 - val_y2_output_root_mean_squared_error: 2.0283
# Epoch 50/500
# 614/614 [==============================] - 0s 154us/sample - loss: 12.2225 - y1_output_loss: 3.6084 - y2_output_loss: 8.5586 - y1_output_root_mean_squared_error: 1.9018 - y2_output_root_mean_squared_error: 2.9335 - val_loss: 13.4767 - val_y1_output_loss: 4.2747 - val_y2_output_loss: 8.9539 - val_y1_output_root_mean_squared_error: 2.0918 - val_y2_output_root_mean_squared_error: 3.0168
# Epoch 51/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.9464 - y1_output_loss: 2.1579 - y2_output_loss: 4.7882 - y1_output_root_mean_squared_error: 1.4617 - y2_output_root_mean_squared_error: 2.1931 - val_loss: 8.2620 - val_y1_output_loss: 3.4282 - val_y2_output_loss: 4.7381 - val_y1_output_root_mean_squared_error: 1.8659 - val_y2_output_root_mean_squared_error: 2.1864
# Epoch 52/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.9040 - y1_output_loss: 2.5200 - y2_output_loss: 5.3193 - y1_output_root_mean_squared_error: 1.5940 - y2_output_root_mean_squared_error: 2.3158 - val_loss: 7.0903 - val_y1_output_loss: 2.8315 - val_y2_output_loss: 4.3693 - val_y1_output_root_mean_squared_error: 1.6813 - val_y2_output_root_mean_squared_error: 2.0648
# Epoch 53/500
# 614/614 [==============================] - 0s 181us/sample - loss: 7.0471 - y1_output_loss: 2.1788 - y2_output_loss: 4.8179 - y1_output_root_mean_squared_error: 1.4822 - y2_output_root_mean_squared_error: 2.2023 - val_loss: 8.8330 - val_y1_output_loss: 2.6831 - val_y2_output_loss: 6.6059 - val_y1_output_root_mean_squared_error: 1.6166 - val_y2_output_root_mean_squared_error: 2.4939
# Epoch 54/500
# 614/614 [==============================] - 0s 149us/sample - loss: 9.9001 - y1_output_loss: 3.1588 - y2_output_loss: 6.6860 - y1_output_root_mean_squared_error: 1.7804 - y2_output_root_mean_squared_error: 2.5942 - val_loss: 7.0759 - val_y1_output_loss: 2.7755 - val_y2_output_loss: 4.2434 - val_y1_output_root_mean_squared_error: 1.6694 - val_y2_output_root_mean_squared_error: 2.0710
# Epoch 55/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.9518 - y1_output_loss: 2.3232 - y2_output_loss: 4.7316 - y1_output_root_mean_squared_error: 1.5042 - y2_output_root_mean_squared_error: 2.1655 - val_loss: 8.0336 - val_y1_output_loss: 2.9626 - val_y2_output_loss: 4.8943 - val_y1_output_root_mean_squared_error: 1.7460 - val_y2_output_root_mean_squared_error: 2.2327
# Epoch 56/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.6417 - y1_output_loss: 2.3748 - y2_output_loss: 5.2376 - y1_output_root_mean_squared_error: 1.5477 - y2_output_root_mean_squared_error: 2.2904 - val_loss: 26.2441 - val_y1_output_loss: 7.2334 - val_y2_output_loss: 20.5325 - val_y1_output_root_mean_squared_error: 2.6093 - val_y2_output_root_mean_squared_error: 4.4086
# Epoch 57/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.1881 - y1_output_loss: 2.3281 - y2_output_loss: 4.9014 - y1_output_root_mean_squared_error: 1.5179 - y2_output_root_mean_squared_error: 2.2100 - val_loss: 17.4607 - val_y1_output_loss: 5.5670 - val_y2_output_loss: 11.3803 - val_y1_output_root_mean_squared_error: 2.3979 - val_y2_output_root_mean_squared_error: 3.4221
# Epoch 58/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.6694 - y1_output_loss: 2.2929 - y2_output_loss: 4.3931 - y1_output_root_mean_squared_error: 1.5022 - y2_output_root_mean_squared_error: 2.1007 - val_loss: 8.0341 - val_y1_output_loss: 3.5481 - val_y2_output_loss: 4.4998 - val_y1_output_root_mean_squared_error: 1.8893 - val_y2_output_root_mean_squared_error: 2.1129
# Epoch 59/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.2935 - y1_output_loss: 2.1095 - y2_output_loss: 5.1547 - y1_output_root_mean_squared_error: 1.4493 - y2_output_root_mean_squared_error: 2.2788 - val_loss: 10.1509 - val_y1_output_loss: 3.8686 - val_y2_output_loss: 6.0299 - val_y1_output_root_mean_squared_error: 1.9946 - val_y2_output_root_mean_squared_error: 2.4845
# Epoch 60/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.7644 - y1_output_loss: 2.6134 - y2_output_loss: 6.1894 - y1_output_root_mean_squared_error: 1.6122 - y2_output_root_mean_squared_error: 2.4830 - val_loss: 12.0542 - val_y1_output_loss: 3.9146 - val_y2_output_loss: 8.4017 - val_y1_output_root_mean_squared_error: 1.9729 - val_y2_output_root_mean_squared_error: 2.8569
# Epoch 61/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.3886 - y1_output_loss: 1.9454 - y2_output_loss: 4.4152 - y1_output_root_mean_squared_error: 1.3963 - y2_output_root_mean_squared_error: 2.1069 - val_loss: 7.9722 - val_y1_output_loss: 3.4005 - val_y2_output_loss: 4.5463 - val_y1_output_root_mean_squared_error: 1.8550 - val_y2_output_root_mean_squared_error: 2.1287
# Epoch 62/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.2240 - y1_output_loss: 2.3608 - y2_output_loss: 4.8164 - y1_output_root_mean_squared_error: 1.5390 - y2_output_root_mean_squared_error: 2.2035 - val_loss: 5.6621 - val_y1_output_loss: 2.1671 - val_y2_output_loss: 3.5252 - val_y1_output_root_mean_squared_error: 1.4699 - val_y2_output_root_mean_squared_error: 1.8712
# Epoch 63/500
# 614/614 [==============================] - 0s 149us/sample - loss: 10.5057 - y1_output_loss: 3.0117 - y2_output_loss: 7.4398 - y1_output_root_mean_squared_error: 1.7409 - y2_output_root_mean_squared_error: 2.7340 - val_loss: 6.2583 - val_y1_output_loss: 2.3477 - val_y2_output_loss: 4.0201 - val_y1_output_root_mean_squared_error: 1.5377 - val_y2_output_root_mean_squared_error: 1.9732
# Epoch 64/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.7820 - y1_output_loss: 1.7600 - y2_output_loss: 3.9903 - y1_output_root_mean_squared_error: 1.3291 - y2_output_root_mean_squared_error: 2.0038 - val_loss: 6.7838 - val_y1_output_loss: 2.1470 - val_y2_output_loss: 4.4842 - val_y1_output_root_mean_squared_error: 1.4833 - val_y2_output_root_mean_squared_error: 2.1409
# Epoch 65/500
# 614/614 [==============================] - 0s 156us/sample - loss: 6.8919 - y1_output_loss: 2.0750 - y2_output_loss: 4.7984 - y1_output_root_mean_squared_error: 1.4456 - y2_output_root_mean_squared_error: 2.1914 - val_loss: 5.5867 - val_y1_output_loss: 2.0161 - val_y2_output_loss: 3.6290 - val_y1_output_root_mean_squared_error: 1.4347 - val_y2_output_root_mean_squared_error: 1.8784
# Epoch 66/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.3762 - y1_output_loss: 1.7269 - y2_output_loss: 3.7231 - y1_output_root_mean_squared_error: 1.3156 - y2_output_root_mean_squared_error: 1.9093 - val_loss: 41.1579 - val_y1_output_loss: 8.9922 - val_y2_output_loss: 32.9086 - val_y1_output_root_mean_squared_error: 2.9779 - val_y2_output_root_mean_squared_error: 5.6824
# Epoch 67/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.9314 - y1_output_loss: 1.6811 - y2_output_loss: 4.2155 - y1_output_root_mean_squared_error: 1.3006 - y2_output_root_mean_squared_error: 2.0591 - val_loss: 5.4577 - val_y1_output_loss: 2.0135 - val_y2_output_loss: 3.3434 - val_y1_output_root_mean_squared_error: 1.4401 - val_y2_output_root_mean_squared_error: 1.8395
# Epoch 68/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.8703 - y1_output_loss: 1.6976 - y2_output_loss: 4.1454 - y1_output_root_mean_squared_error: 1.3017 - y2_output_root_mean_squared_error: 2.0435 - val_loss: 4.9426 - val_y1_output_loss: 1.7908 - val_y2_output_loss: 3.0876 - val_y1_output_root_mean_squared_error: 1.3531 - val_y2_output_root_mean_squared_error: 1.7640
# Epoch 69/500
# 614/614 [==============================] - 0s 160us/sample - loss: 4.9850 - y1_output_loss: 1.5044 - y2_output_loss: 3.4656 - y1_output_root_mean_squared_error: 1.2320 - y2_output_root_mean_squared_error: 1.8620 - val_loss: 6.5534 - val_y1_output_loss: 2.1263 - val_y2_output_loss: 4.7499 - val_y1_output_root_mean_squared_error: 1.4327 - val_y2_output_root_mean_squared_error: 2.1215
# Epoch 70/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.2162 - y1_output_loss: 1.4667 - y2_output_loss: 3.7450 - y1_output_root_mean_squared_error: 1.2108 - y2_output_root_mean_squared_error: 1.9365 - val_loss: 5.4612 - val_y1_output_loss: 2.2129 - val_y2_output_loss: 3.2704 - val_y1_output_root_mean_squared_error: 1.4924 - val_y2_output_root_mean_squared_error: 1.7983
# Epoch 71/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.5497 - y1_output_loss: 1.8736 - y2_output_loss: 4.7014 - y1_output_root_mean_squared_error: 1.3750 - y2_output_root_mean_squared_error: 2.1585 - val_loss: 14.7864 - val_y1_output_loss: 2.6210 - val_y2_output_loss: 11.8372 - val_y1_output_root_mean_squared_error: 1.6399 - val_y2_output_root_mean_squared_error: 3.4781
# Epoch 72/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.6301 - y1_output_loss: 1.7430 - y2_output_loss: 4.8414 - y1_output_root_mean_squared_error: 1.3210 - y2_output_root_mean_squared_error: 2.2102 - val_loss: 6.8379 - val_y1_output_loss: 2.5815 - val_y2_output_loss: 4.0403 - val_y1_output_root_mean_squared_error: 1.6366 - val_y2_output_root_mean_squared_error: 2.0394
# Epoch 73/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.9759 - y1_output_loss: 1.4361 - y2_output_loss: 3.5710 - y1_output_root_mean_squared_error: 1.1965 - y2_output_root_mean_squared_error: 1.8826 - val_loss: 4.8299 - val_y1_output_loss: 1.7809 - val_y2_output_loss: 3.3121 - val_y1_output_root_mean_squared_error: 1.3075 - val_y2_output_root_mean_squared_error: 1.7664
# Epoch 74/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.1896 - y1_output_loss: 1.3961 - y2_output_loss: 3.7849 - y1_output_root_mean_squared_error: 1.1738 - y2_output_root_mean_squared_error: 1.9524 - val_loss: 4.7092 - val_y1_output_loss: 1.8393 - val_y2_output_loss: 2.8518 - val_y1_output_root_mean_squared_error: 1.3625 - val_y2_output_root_mean_squared_error: 1.6890
# Epoch 75/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.7210 - y1_output_loss: 1.3487 - y2_output_loss: 3.3351 - y1_output_root_mean_squared_error: 1.1658 - y2_output_root_mean_squared_error: 1.8335 - val_loss: 5.7187 - val_y1_output_loss: 1.9289 - val_y2_output_loss: 4.1107 - val_y1_output_root_mean_squared_error: 1.3691 - val_y2_output_root_mean_squared_error: 1.9607
# Epoch 76/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.5628 - y1_output_loss: 1.3347 - y2_output_loss: 3.1953 - y1_output_root_mean_squared_error: 1.1585 - y2_output_root_mean_squared_error: 1.7947 - val_loss: 5.1028 - val_y1_output_loss: 1.5805 - val_y2_output_loss: 3.6801 - val_y1_output_root_mean_squared_error: 1.2497 - val_y2_output_root_mean_squared_error: 1.8818
# Epoch 77/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.7543 - y1_output_loss: 1.4123 - y2_output_loss: 4.3540 - y1_output_root_mean_squared_error: 1.1910 - y2_output_root_mean_squared_error: 2.0823 - val_loss: 5.1874 - val_y1_output_loss: 2.1582 - val_y2_output_loss: 3.1701 - val_y1_output_root_mean_squared_error: 1.4525 - val_y2_output_root_mean_squared_error: 1.7543
# Epoch 78/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.5611 - y1_output_loss: 1.2087 - y2_output_loss: 3.3371 - y1_output_root_mean_squared_error: 1.1039 - y2_output_root_mean_squared_error: 1.8282 - val_loss: 7.5204 - val_y1_output_loss: 1.9434 - val_y2_output_loss: 5.6751 - val_y1_output_root_mean_squared_error: 1.3982 - val_y2_output_root_mean_squared_error: 2.3591
# Epoch 79/500
# 614/614 [==============================] - 0s 164us/sample - loss: 4.4977 - y1_output_loss: 1.4758 - y2_output_loss: 2.9923 - y1_output_root_mean_squared_error: 1.2193 - y2_output_root_mean_squared_error: 1.7352 - val_loss: 8.7286 - val_y1_output_loss: 2.6645 - val_y2_output_loss: 6.1756 - val_y1_output_root_mean_squared_error: 1.6326 - val_y2_output_root_mean_squared_error: 2.4623
# Epoch 80/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.1724 - y1_output_loss: 1.1014 - y2_output_loss: 3.0430 - y1_output_root_mean_squared_error: 1.0525 - y2_output_root_mean_squared_error: 1.7506 - val_loss: 5.4428 - val_y1_output_loss: 1.4946 - val_y2_output_loss: 3.9442 - val_y1_output_root_mean_squared_error: 1.2390 - val_y2_output_root_mean_squared_error: 1.9768
# Epoch 81/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.5544 - y1_output_loss: 1.0558 - y2_output_loss: 3.4793 - y1_output_root_mean_squared_error: 1.0262 - y2_output_root_mean_squared_error: 1.8712 - val_loss: 3.8090 - val_y1_output_loss: 1.2430 - val_y2_output_loss: 2.6596 - val_y1_output_root_mean_squared_error: 1.1107 - val_y2_output_root_mean_squared_error: 1.6048
# Epoch 82/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.0527 - y1_output_loss: 1.2946 - y2_output_loss: 3.7225 - y1_output_root_mean_squared_error: 1.1400 - y2_output_root_mean_squared_error: 1.9373 - val_loss: 5.8691 - val_y1_output_loss: 2.0963 - val_y2_output_loss: 3.6873 - val_y1_output_root_mean_squared_error: 1.4601 - val_y2_output_root_mean_squared_error: 1.9332
# Epoch 83/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.2322 - y1_output_loss: 1.0577 - y2_output_loss: 3.1790 - y1_output_root_mean_squared_error: 1.0311 - y2_output_root_mean_squared_error: 1.7802 - val_loss: 3.8110 - val_y1_output_loss: 1.2859 - val_y2_output_loss: 2.4627 - val_y1_output_root_mean_squared_error: 1.1462 - val_y2_output_root_mean_squared_error: 1.5803
# Epoch 84/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.4796 - y1_output_loss: 1.1470 - y2_output_loss: 3.3328 - y1_output_root_mean_squared_error: 1.0757 - y2_output_root_mean_squared_error: 1.8228 - val_loss: 6.6467 - val_y1_output_loss: 1.5585 - val_y2_output_loss: 5.3086 - val_y1_output_root_mean_squared_error: 1.2382 - val_y2_output_root_mean_squared_error: 2.2613
# Epoch 85/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.9678 - y1_output_loss: 1.0729 - y2_output_loss: 2.8645 - y1_output_root_mean_squared_error: 1.0402 - y2_output_root_mean_squared_error: 1.6988 - val_loss: 4.0117 - val_y1_output_loss: 1.2152 - val_y2_output_loss: 2.7794 - val_y1_output_root_mean_squared_error: 1.1163 - val_y2_output_root_mean_squared_error: 1.6630
# Epoch 86/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.9044 - y1_output_loss: 1.1891 - y2_output_loss: 3.7168 - y1_output_root_mean_squared_error: 1.0926 - y2_output_root_mean_squared_error: 1.9263 - val_loss: 4.5655 - val_y1_output_loss: 1.0026 - val_y2_output_loss: 3.6571 - val_y1_output_root_mean_squared_error: 1.0051 - val_y2_output_root_mean_squared_error: 1.8856
# Epoch 87/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.3114 - y1_output_loss: 1.1418 - y2_output_loss: 3.1961 - y1_output_root_mean_squared_error: 1.0633 - y2_output_root_mean_squared_error: 1.7835 - val_loss: 14.8479 - val_y1_output_loss: 5.5557 - val_y2_output_loss: 9.1299 - val_y1_output_root_mean_squared_error: 2.3733 - val_y2_output_root_mean_squared_error: 3.0357
# Epoch 88/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.1913 - y1_output_loss: 1.2493 - y2_output_loss: 2.9117 - y1_output_root_mean_squared_error: 1.1216 - y2_output_root_mean_squared_error: 1.7127 - val_loss: 6.0277 - val_y1_output_loss: 2.4367 - val_y2_output_loss: 3.5187 - val_y1_output_root_mean_squared_error: 1.5770 - val_y2_output_root_mean_squared_error: 1.8817
# Epoch 89/500
# 614/614 [==============================] - 0s 189us/sample - loss: 3.1355 - y1_output_loss: 0.8494 - y2_output_loss: 2.2801 - y1_output_root_mean_squared_error: 0.9257 - y2_output_root_mean_squared_error: 1.5095 - val_loss: 5.7869 - val_y1_output_loss: 1.3962 - val_y2_output_loss: 4.4025 - val_y1_output_root_mean_squared_error: 1.1801 - val_y2_output_root_mean_squared_error: 2.0962
# Epoch 90/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.6439 - y1_output_loss: 0.8958 - y2_output_loss: 2.7910 - y1_output_root_mean_squared_error: 0.9454 - y2_output_root_mean_squared_error: 1.6584 - val_loss: 4.3701 - val_y1_output_loss: 1.1160 - val_y2_output_loss: 3.1182 - val_y1_output_root_mean_squared_error: 1.0695 - val_y2_output_root_mean_squared_error: 1.7962
# Epoch 91/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.2540 - y1_output_loss: 0.7485 - y2_output_loss: 2.4909 - y1_output_root_mean_squared_error: 0.8616 - y2_output_root_mean_squared_error: 1.5848 - val_loss: 3.5461 - val_y1_output_loss: 1.1884 - val_y2_output_loss: 2.3083 - val_y1_output_root_mean_squared_error: 1.1031 - val_y2_output_root_mean_squared_error: 1.5262
# Epoch 92/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.5132 - y1_output_loss: 0.8133 - y2_output_loss: 2.7170 - y1_output_root_mean_squared_error: 0.9055 - y2_output_root_mean_squared_error: 1.6411 - val_loss: 8.4596 - val_y1_output_loss: 1.1467 - val_y2_output_loss: 7.1712 - val_y1_output_root_mean_squared_error: 1.0876 - val_y2_output_root_mean_squared_error: 2.6975
# Epoch 93/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.3498 - y1_output_loss: 0.8237 - y2_output_loss: 2.5150 - y1_output_root_mean_squared_error: 0.9035 - y2_output_root_mean_squared_error: 1.5917 - val_loss: 4.6925 - val_y1_output_loss: 1.1738 - val_y2_output_loss: 3.4789 - val_y1_output_root_mean_squared_error: 1.0898 - val_y2_output_root_mean_squared_error: 1.8721
# Epoch 94/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.4024 - y1_output_loss: 0.7994 - y2_output_loss: 2.5949 - y1_output_root_mean_squared_error: 0.8955 - y2_output_root_mean_squared_error: 1.6126 - val_loss: 4.4014 - val_y1_output_loss: 0.8610 - val_y2_output_loss: 3.4356 - val_y1_output_root_mean_squared_error: 0.9345 - val_y2_output_root_mean_squared_error: 1.8783
# Epoch 95/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7423 - y1_output_loss: 0.6783 - y2_output_loss: 2.0705 - y1_output_root_mean_squared_error: 0.8252 - y2_output_root_mean_squared_error: 1.4357 - val_loss: 6.2581 - val_y1_output_loss: 1.3555 - val_y2_output_loss: 4.7518 - val_y1_output_root_mean_squared_error: 1.1817 - val_y2_output_root_mean_squared_error: 2.2049
# Epoch 96/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.8706 - y1_output_loss: 0.7259 - y2_output_loss: 2.1337 - y1_output_root_mean_squared_error: 0.8521 - y2_output_root_mean_squared_error: 1.4644 - val_loss: 4.1155 - val_y1_output_loss: 1.5388 - val_y2_output_loss: 2.5116 - val_y1_output_root_mean_squared_error: 1.2516 - val_y2_output_root_mean_squared_error: 1.5965
# Epoch 97/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.1116 - y1_output_loss: 0.7333 - y2_output_loss: 2.3784 - y1_output_root_mean_squared_error: 0.8540 - y2_output_root_mean_squared_error: 1.5435 - val_loss: 2.7063 - val_y1_output_loss: 0.7629 - val_y2_output_loss: 1.8788 - val_y1_output_root_mean_squared_error: 0.8858 - val_y2_output_root_mean_squared_error: 1.3862
# Epoch 98/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.5985 - y1_output_loss: 0.8136 - y2_output_loss: 2.7591 - y1_output_root_mean_squared_error: 0.9036 - y2_output_root_mean_squared_error: 1.6679 - val_loss: 2.6387 - val_y1_output_loss: 0.7019 - val_y2_output_loss: 1.9199 - val_y1_output_root_mean_squared_error: 0.8520 - val_y2_output_root_mean_squared_error: 1.3831
# Epoch 99/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.4913 - y1_output_loss: 0.8262 - y2_output_loss: 2.7211 - y1_output_root_mean_squared_error: 0.9125 - y2_output_root_mean_squared_error: 1.6305 - val_loss: 4.9327 - val_y1_output_loss: 1.5480 - val_y2_output_loss: 3.3314 - val_y1_output_root_mean_squared_error: 1.2583 - val_y2_output_root_mean_squared_error: 1.8301
# Epoch 100/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.1458 - y1_output_loss: 0.8268 - y2_output_loss: 2.3117 - y1_output_root_mean_squared_error: 0.9136 - y2_output_root_mean_squared_error: 1.5202 - val_loss: 4.0696 - val_y1_output_loss: 0.7629 - val_y2_output_loss: 3.3252 - val_y1_output_root_mean_squared_error: 0.8803 - val_y2_output_root_mean_squared_error: 1.8151
# Epoch 101/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.0589 - y1_output_loss: 0.8181 - y2_output_loss: 2.2337 - y1_output_root_mean_squared_error: 0.9076 - y2_output_root_mean_squared_error: 1.4951 - val_loss: 4.6542 - val_y1_output_loss: 1.2681 - val_y2_output_loss: 3.3618 - val_y1_output_root_mean_squared_error: 1.1383 - val_y2_output_root_mean_squared_error: 1.8326
# Epoch 102/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.0938 - y1_output_loss: 0.7089 - y2_output_loss: 2.3644 - y1_output_root_mean_squared_error: 0.8420 - y2_output_root_mean_squared_error: 1.5443 - val_loss: 2.8646 - val_y1_output_loss: 0.8399 - val_y2_output_loss: 1.9648 - val_y1_output_root_mean_squared_error: 0.9298 - val_y2_output_root_mean_squared_error: 1.4142
# Epoch 103/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.7384 - y1_output_loss: 0.6212 - y2_output_loss: 2.1078 - y1_output_root_mean_squared_error: 0.7890 - y2_output_root_mean_squared_error: 1.4546 - val_loss: 2.9537 - val_y1_output_loss: 0.9663 - val_y2_output_loss: 1.9472 - val_y1_output_root_mean_squared_error: 0.9964 - val_y2_output_root_mean_squared_error: 1.4004
# Epoch 104/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.0138 - y1_output_loss: 0.7242 - y2_output_loss: 2.2755 - y1_output_root_mean_squared_error: 0.8545 - y2_output_root_mean_squared_error: 1.5112 - val_loss: 5.9934 - val_y1_output_loss: 1.3505 - val_y2_output_loss: 4.5327 - val_y1_output_root_mean_squared_error: 1.1817 - val_y2_output_root_mean_squared_error: 2.1441
# Epoch 105/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.0789 - y1_output_loss: 1.0349 - y2_output_loss: 3.1228 - y1_output_root_mean_squared_error: 1.0140 - y2_output_root_mean_squared_error: 1.7466 - val_loss: 3.6140 - val_y1_output_loss: 0.7935 - val_y2_output_loss: 2.7839 - val_y1_output_root_mean_squared_error: 0.9000 - val_y2_output_root_mean_squared_error: 1.6745
# Epoch 106/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7170 - y1_output_loss: 0.7008 - y2_output_loss: 2.0208 - y1_output_root_mean_squared_error: 0.8353 - y2_output_root_mean_squared_error: 1.4210 - val_loss: 7.0025 - val_y1_output_loss: 1.3061 - val_y2_output_loss: 5.6861 - val_y1_output_root_mean_squared_error: 1.1509 - val_y2_output_root_mean_squared_error: 2.3828
# Epoch 107/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.7766 - y1_output_loss: 1.4543 - y2_output_loss: 3.3086 - y1_output_root_mean_squared_error: 1.2060 - y2_output_root_mean_squared_error: 1.8227 - val_loss: 13.6356 - val_y1_output_loss: 4.6451 - val_y2_output_loss: 8.9961 - val_y1_output_root_mean_squared_error: 2.1634 - val_y2_output_root_mean_squared_error: 2.9926
# Epoch 108/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6530 - y1_output_loss: 0.6289 - y2_output_loss: 2.0842 - y1_output_root_mean_squared_error: 0.7960 - y2_output_root_mean_squared_error: 1.4210 - val_loss: 7.2217 - val_y1_output_loss: 1.2960 - val_y2_output_loss: 5.8006 - val_y1_output_root_mean_squared_error: 1.1581 - val_y2_output_root_mean_squared_error: 2.4250
# Epoch 109/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5777 - y1_output_loss: 0.5638 - y2_output_loss: 1.9939 - y1_output_root_mean_squared_error: 0.7540 - y2_output_root_mean_squared_error: 1.4175 - val_loss: 2.5832 - val_y1_output_loss: 0.8148 - val_y2_output_loss: 1.7106 - val_y1_output_root_mean_squared_error: 0.9166 - val_y2_output_root_mean_squared_error: 1.3202
# Epoch 110/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.1319 - y1_output_loss: 0.8501 - y2_output_loss: 2.2581 - y1_output_root_mean_squared_error: 0.9235 - y2_output_root_mean_squared_error: 1.5096 - val_loss: 4.6238 - val_y1_output_loss: 1.6692 - val_y2_output_loss: 2.8882 - val_y1_output_root_mean_squared_error: 1.3002 - val_y2_output_root_mean_squared_error: 1.7127
# Epoch 111/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.0578 - y1_output_loss: 0.6910 - y2_output_loss: 2.3436 - y1_output_root_mean_squared_error: 0.8351 - y2_output_root_mean_squared_error: 1.5363 - val_loss: 3.2036 - val_y1_output_loss: 0.7185 - val_y2_output_loss: 2.4725 - val_y1_output_root_mean_squared_error: 0.8570 - val_y2_output_root_mean_squared_error: 1.5713
# Epoch 112/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.1775 - y1_output_loss: 0.8229 - y2_output_loss: 2.3534 - y1_output_root_mean_squared_error: 0.9025 - y2_output_root_mean_squared_error: 1.5372 - val_loss: 5.8687 - val_y1_output_loss: 2.0451 - val_y2_output_loss: 3.7604 - val_y1_output_root_mean_squared_error: 1.4313 - val_y2_output_root_mean_squared_error: 1.9545
# Epoch 113/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.5558 - y1_output_loss: 0.7997 - y2_output_loss: 2.7760 - y1_output_root_mean_squared_error: 0.8935 - y2_output_root_mean_squared_error: 1.6606 - val_loss: 13.9818 - val_y1_output_loss: 2.1204 - val_y2_output_loss: 11.8863 - val_y1_output_root_mean_squared_error: 1.4648 - val_y2_output_root_mean_squared_error: 3.4404
# Epoch 114/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.1688 - y1_output_loss: 1.3674 - y2_output_loss: 3.7563 - y1_output_root_mean_squared_error: 1.1736 - y2_output_root_mean_squared_error: 1.9472 - val_loss: 2.3257 - val_y1_output_loss: 0.6512 - val_y2_output_loss: 1.6355 - val_y1_output_root_mean_squared_error: 0.8150 - val_y2_output_root_mean_squared_error: 1.2889
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1248 - y1_output_loss: 0.7048 - y2_output_loss: 2.3964 - y1_output_root_mean_squared_error: 0.8408 - y2_output_root_mean_squared_error: 1.5550 - val_loss: 3.9344 - val_y1_output_loss: 1.6732 - val_y2_output_loss: 2.1605 - val_y1_output_root_mean_squared_error: 1.3109 - val_y2_output_root_mean_squared_error: 1.4886
# Epoch 116/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.3038 - y1_output_loss: 1.4204 - y2_output_loss: 3.8446 - y1_output_root_mean_squared_error: 1.1974 - y2_output_root_mean_squared_error: 1.9672 - val_loss: 2.9621 - val_y1_output_loss: 1.0267 - val_y2_output_loss: 1.9131 - val_y1_output_root_mean_squared_error: 1.0258 - val_y2_output_root_mean_squared_error: 1.3819
# Epoch 117/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.4464 - y1_output_loss: 0.6424 - y2_output_loss: 1.8183 - y1_output_root_mean_squared_error: 0.7953 - y2_output_root_mean_squared_error: 1.3468 - val_loss: 2.6886 - val_y1_output_loss: 0.7958 - val_y2_output_loss: 1.8880 - val_y1_output_root_mean_squared_error: 0.9037 - val_y2_output_root_mean_squared_error: 1.3682
# Epoch 118/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3136 - y1_output_loss: 0.7486 - y2_output_loss: 2.5915 - y1_output_root_mean_squared_error: 0.8639 - y2_output_root_mean_squared_error: 1.6023 - val_loss: 7.9550 - val_y1_output_loss: 0.9931 - val_y2_output_loss: 6.9554 - val_y1_output_root_mean_squared_error: 0.9931 - val_y2_output_root_mean_squared_error: 2.6398
# Epoch 119/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.4514 - y1_output_loss: 0.5655 - y2_output_loss: 1.8743 - y1_output_root_mean_squared_error: 0.7543 - y2_output_root_mean_squared_error: 1.3720 - val_loss: 2.5375 - val_y1_output_loss: 0.5265 - val_y2_output_loss: 1.9798 - val_y1_output_root_mean_squared_error: 0.7391 - val_y2_output_root_mean_squared_error: 1.4111
# Epoch 120/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.7945 - y1_output_loss: 1.1058 - y2_output_loss: 2.6585 - y1_output_root_mean_squared_error: 1.0541 - y2_output_root_mean_squared_error: 1.6381 - val_loss: 2.4379 - val_y1_output_loss: 0.6827 - val_y2_output_loss: 1.7131 - val_y1_output_root_mean_squared_error: 0.8312 - val_y2_output_root_mean_squared_error: 1.3217
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3480 - y1_output_loss: 0.1215 - y2_output_loss: 0.2254 - y1_output_root_mean_squared_error: 0.3496 - y2_output_root_mean_squared_error: 0.4752 - val_loss: 0.8968 - val_y1_output_loss: 0.2307 - val_y2_output_loss: 0.6532 - val_y1_output_root_mean_squared_error: 0.4873 - val_y2_output_root_mean_squared_error: 0.8120
# Epoch 462/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3519 - y1_output_loss: 0.1077 - y2_output_loss: 0.2427 - y1_output_root_mean_squared_error: 0.3278 - y2_output_root_mean_squared_error: 0.4944 - val_loss: 0.7201 - val_y1_output_loss: 0.2161 - val_y2_output_loss: 0.4945 - val_y1_output_root_mean_squared_error: 0.4707 - val_y2_output_root_mean_squared_error: 0.7060
# Epoch 463/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3507 - y1_output_loss: 0.1088 - y2_output_loss: 0.2418 - y1_output_root_mean_squared_error: 0.3286 - y2_output_root_mean_squared_error: 0.4927 - val_loss: 0.6813 - val_y1_output_loss: 0.2015 - val_y2_output_loss: 0.4739 - val_y1_output_root_mean_squared_error: 0.4551 - val_y2_output_root_mean_squared_error: 0.6886
# Epoch 464/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3364 - y1_output_loss: 0.1050 - y2_output_loss: 0.2290 - y1_output_root_mean_squared_error: 0.3246 - y2_output_root_mean_squared_error: 0.4807 - val_loss: 0.6562 - val_y1_output_loss: 0.1886 - val_y2_output_loss: 0.4622 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 0.6796
# Epoch 465/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3081 - y1_output_loss: 0.1030 - y2_output_loss: 0.2036 - y1_output_root_mean_squared_error: 0.3216 - y2_output_root_mean_squared_error: 0.4524 - val_loss: 0.8217 - val_y1_output_loss: 0.2830 - val_y2_output_loss: 0.5310 - val_y1_output_root_mean_squared_error: 0.5394 - val_y2_output_root_mean_squared_error: 0.7285
# Epoch 466/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3185 - y1_output_loss: 0.1213 - y2_output_loss: 0.1985 - y1_output_root_mean_squared_error: 0.3478 - y2_output_root_mean_squared_error: 0.4444 - val_loss: 1.1847 - val_y1_output_loss: 0.3054 - val_y2_output_loss: 0.8817 - val_y1_output_root_mean_squared_error: 0.5531 - val_y2_output_root_mean_squared_error: 0.9375
# Epoch 467/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5574 - y1_output_loss: 0.1591 - y2_output_loss: 0.4106 - y1_output_root_mean_squared_error: 0.3989 - y2_output_root_mean_squared_error: 0.6311 - val_loss: 4.6886 - val_y1_output_loss: 0.2891 - val_y2_output_loss: 4.3996 - val_y1_output_root_mean_squared_error: 0.5432 - val_y2_output_root_mean_squared_error: 2.0961
# Epoch 468/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4529 - y1_output_loss: 0.1426 - y2_output_loss: 0.3104 - y1_output_root_mean_squared_error: 0.3767 - y2_output_root_mean_squared_error: 0.5577 - val_loss: 1.5477 - val_y1_output_loss: 0.5089 - val_y2_output_loss: 1.0172 - val_y1_output_root_mean_squared_error: 0.7246 - val_y2_output_root_mean_squared_error: 1.0113
# Epoch 469/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5371 - y1_output_loss: 0.1301 - y2_output_loss: 0.4032 - y1_output_root_mean_squared_error: 0.3615 - y2_output_root_mean_squared_error: 0.6375 - val_loss: 0.8793 - val_y1_output_loss: 0.2882 - val_y2_output_loss: 0.5887 - val_y1_output_root_mean_squared_error: 0.5379 - val_y2_output_root_mean_squared_error: 0.7681
# Epoch 470/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3389 - y1_output_loss: 0.1145 - y2_output_loss: 0.2280 - y1_output_root_mean_squared_error: 0.3388 - y2_output_root_mean_squared_error: 0.4734 - val_loss: 2.5028 - val_y1_output_loss: 0.4567 - val_y2_output_loss: 2.0163 - val_y1_output_root_mean_squared_error: 0.6867 - val_y2_output_root_mean_squared_error: 1.4252
# Epoch 471/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4008 - y1_output_loss: 0.1214 - y2_output_loss: 0.2783 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.5283 - val_loss: 0.6720 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 0.4602 - val_y1_output_root_mean_squared_error: 0.4559 - val_y2_output_root_mean_squared_error: 0.6813
# Epoch 472/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2964 - y1_output_loss: 0.1016 - y2_output_loss: 0.1933 - y1_output_root_mean_squared_error: 0.3201 - y2_output_root_mean_squared_error: 0.4404 - val_loss: 0.7924 - val_y1_output_loss: 0.2374 - val_y2_output_loss: 0.5506 - val_y1_output_root_mean_squared_error: 0.4921 - val_y2_output_root_mean_squared_error: 0.7418
# Epoch 473/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3358 - y1_output_loss: 0.0975 - y2_output_loss: 0.2362 - y1_output_root_mean_squared_error: 0.3130 - y2_output_root_mean_squared_error: 0.4877 - val_loss: 0.8489 - val_y1_output_loss: 0.2236 - val_y2_output_loss: 0.6204 - val_y1_output_root_mean_squared_error: 0.4787 - val_y2_output_root_mean_squared_error: 0.7872
# Epoch 474/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3516 - y1_output_loss: 0.1196 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3471 - y2_output_root_mean_squared_error: 0.4808 - val_loss: 0.7381 - val_y1_output_loss: 0.2070 - val_y2_output_loss: 0.5234 - val_y1_output_root_mean_squared_error: 0.4615 - val_y2_output_root_mean_squared_error: 0.7247
# Epoch 475/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4193 - y1_output_loss: 0.1331 - y2_output_loss: 0.2930 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.5359 - val_loss: 2.0443 - val_y1_output_loss: 0.4087 - val_y2_output_loss: 1.6246 - val_y1_output_root_mean_squared_error: 0.6425 - val_y2_output_root_mean_squared_error: 1.2773
# Epoch 476/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.7338 - y1_output_loss: 0.1797 - y2_output_loss: 0.5494 - y1_output_root_mean_squared_error: 0.4250 - y2_output_root_mean_squared_error: 0.7438 - val_loss: 0.8124 - val_y1_output_loss: 0.2567 - val_y2_output_loss: 0.5696 - val_y1_output_root_mean_squared_error: 0.5051 - val_y2_output_root_mean_squared_error: 0.7465
# Epoch 477/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.5635 - y1_output_loss: 0.1493 - y2_output_loss: 0.4495 - y1_output_root_mean_squared_error: 0.3842 - y2_output_root_mean_squared_error: 0.6449 - val_loss: 9.1868 - val_y1_output_loss: 2.1548 - val_y2_output_loss: 7.2021 - val_y1_output_root_mean_squared_error: 1.4632 - val_y2_output_root_mean_squared_error: 2.6544
# Epoch 478/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.9647 - y1_output_loss: 0.2886 - y2_output_loss: 0.6676 - y1_output_root_mean_squared_error: 0.5397 - y2_output_root_mean_squared_error: 0.8206 - val_loss: 0.7419 - val_y1_output_loss: 0.2081 - val_y2_output_loss: 0.5247 - val_y1_output_root_mean_squared_error: 0.4620 - val_y2_output_root_mean_squared_error: 0.7269
# Epoch 479/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.2992 - y1_output_loss: 0.0963 - y2_output_loss: 0.2030 - y1_output_root_mean_squared_error: 0.3108 - y2_output_root_mean_squared_error: 0.4502 - val_loss: 1.0542 - val_y1_output_loss: 0.2120 - val_y2_output_loss: 0.8486 - val_y1_output_root_mean_squared_error: 0.4663 - val_y2_output_root_mean_squared_error: 0.9147
# Epoch 480/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3879 - y1_output_loss: 0.1161 - y2_output_loss: 0.2849 - y1_output_root_mean_squared_error: 0.3390 - y2_output_root_mean_squared_error: 0.5225 - val_loss: 2.1221 - val_y1_output_loss: 0.3891 - val_y2_output_loss: 1.7402 - val_y1_output_root_mean_squared_error: 0.6252 - val_y2_output_root_mean_squared_error: 1.3158
# Epoch 481/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3219 - y1_output_loss: 0.1108 - y2_output_loss: 0.2173 - y1_output_root_mean_squared_error: 0.3326 - y2_output_root_mean_squared_error: 0.4597 - val_loss: 1.0239 - val_y1_output_loss: 0.2208 - val_y2_output_loss: 0.8000 - val_y1_output_root_mean_squared_error: 0.4765 - val_y2_output_root_mean_squared_error: 0.8926
# Epoch 482/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3513 - y1_output_loss: 0.1225 - y2_output_loss: 0.2329 - y1_output_root_mean_squared_error: 0.3508 - y2_output_root_mean_squared_error: 0.4777 - val_loss: 1.0964 - val_y1_output_loss: 0.2807 - val_y2_output_loss: 0.8142 - val_y1_output_root_mean_squared_error: 0.5331 - val_y2_output_root_mean_squared_error: 0.9012
# Epoch 483/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3629 - y1_output_loss: 0.1184 - y2_output_loss: 0.2526 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.5002 - val_loss: 4.7421 - val_y1_output_loss: 1.6135 - val_y2_output_loss: 3.0340 - val_y1_output_root_mean_squared_error: 1.2883 - val_y2_output_root_mean_squared_error: 1.7557
# Epoch 484/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4292 - y1_output_loss: 0.1356 - y2_output_loss: 0.2960 - y1_output_root_mean_squared_error: 0.3697 - y2_output_root_mean_squared_error: 0.5409 - val_loss: 2.0085 - val_y1_output_loss: 0.2929 - val_y2_output_loss: 1.7149 - val_y1_output_root_mean_squared_error: 0.5473 - val_y2_output_root_mean_squared_error: 1.3073
# Epoch 485/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4434 - y1_output_loss: 0.1934 - y2_output_loss: 0.3565 - y1_output_root_mean_squared_error: 0.3883 - y2_output_root_mean_squared_error: 0.5410 - val_loss: 19.7205 - val_y1_output_loss: 6.9028 - val_y2_output_loss: 12.5243 - val_y1_output_root_mean_squared_error: 2.6540 - val_y2_output_root_mean_squared_error: 3.5604
# Epoch 486/500
# 614/614 [==============================] - 0s 146us/sample - loss: 1.0768 - y1_output_loss: 0.3423 - y2_output_loss: 0.7274 - y1_output_root_mean_squared_error: 0.5872 - y2_output_root_mean_squared_error: 0.8555 - val_loss: 0.9999 - val_y1_output_loss: 0.2104 - val_y2_output_loss: 0.7794 - val_y1_output_root_mean_squared_error: 0.4613 - val_y2_output_root_mean_squared_error: 0.8872
# Epoch 487/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3240 - y1_output_loss: 0.1075 - y2_output_loss: 0.2158 - y1_output_root_mean_squared_error: 0.3275 - y2_output_root_mean_squared_error: 0.4656 - val_loss: 1.1005 - val_y1_output_loss: 0.3454 - val_y2_output_loss: 0.7881 - val_y1_output_root_mean_squared_error: 0.5845 - val_y2_output_root_mean_squared_error: 0.8712
# Epoch 488/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.2919 - y1_output_loss: 0.0966 - y2_output_loss: 0.1938 - y1_output_root_mean_squared_error: 0.3104 - y2_output_root_mean_squared_error: 0.4422 - val_loss: 0.7094 - val_y1_output_loss: 0.2398 - val_y2_output_loss: 0.4716 - val_y1_output_root_mean_squared_error: 0.4894 - val_y2_output_root_mean_squared_error: 0.6854
# Epoch 489/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3068 - y1_output_loss: 0.0981 - y2_output_loss: 0.2070 - y1_output_root_mean_squared_error: 0.3143 - y2_output_root_mean_squared_error: 0.4561 - val_loss: 0.7849 - val_y1_output_loss: 0.2399 - val_y2_output_loss: 0.5320 - val_y1_output_root_mean_squared_error: 0.4952 - val_y2_output_root_mean_squared_error: 0.7346
# Epoch 490/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2957 - y1_output_loss: 0.0904 - y2_output_loss: 0.2033 - y1_output_root_mean_squared_error: 0.3020 - y2_output_root_mean_squared_error: 0.4523 - val_loss: 0.6632 - val_y1_output_loss: 0.2085 - val_y2_output_loss: 0.4432 - val_y1_output_root_mean_squared_error: 0.4629 - val_y2_output_root_mean_squared_error: 0.6700
# Epoch 491/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3053 - y1_output_loss: 0.1078 - y2_output_loss: 0.1971 - y1_output_root_mean_squared_error: 0.3297 - y2_output_root_mean_squared_error: 0.4434 - val_loss: 1.0303 - val_y1_output_loss: 0.3335 - val_y2_output_loss: 0.6788 - val_y1_output_root_mean_squared_error: 0.5874 - val_y2_output_root_mean_squared_error: 0.8278
# Epoch 492/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.2871 - y1_output_loss: 0.1015 - y2_output_loss: 0.1884 - y1_output_root_mean_squared_error: 0.3165 - y2_output_root_mean_squared_error: 0.4323 - val_loss: 1.2259 - val_y1_output_loss: 0.4124 - val_y2_output_loss: 0.8095 - val_y1_output_root_mean_squared_error: 0.6484 - val_y2_output_root_mean_squared_error: 0.8975
# Epoch 493/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3157 - y1_output_loss: 0.1080 - y2_output_loss: 0.2137 - y1_output_root_mean_squared_error: 0.3232 - y2_output_root_mean_squared_error: 0.4596 - val_loss: 1.6594 - val_y1_output_loss: 0.4194 - val_y2_output_loss: 1.3186 - val_y1_output_root_mean_squared_error: 0.6315 - val_y2_output_root_mean_squared_error: 1.1227
# Epoch 494/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3362 - y1_output_loss: 0.1090 - y2_output_loss: 0.2280 - y1_output_root_mean_squared_error: 0.3296 - y2_output_root_mean_squared_error: 0.4771 - val_loss: 1.0966 - val_y1_output_loss: 0.3380 - val_y2_output_loss: 0.7492 - val_y1_output_root_mean_squared_error: 0.5852 - val_y2_output_root_mean_squared_error: 0.8684
# Epoch 495/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3255 - y1_output_loss: 0.1227 - y2_output_loss: 0.2007 - y1_output_root_mean_squared_error: 0.3515 - y2_output_root_mean_squared_error: 0.4494 - val_loss: 0.6507 - val_y1_output_loss: 0.2051 - val_y2_output_loss: 0.4473 - val_y1_output_root_mean_squared_error: 0.4591 - val_y2_output_root_mean_squared_error: 0.6633
# Epoch 496/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2725 - y1_output_loss: 0.0986 - y2_output_loss: 0.1762 - y1_output_root_mean_squared_error: 0.3139 - y2_output_root_mean_squared_error: 0.4172 - val_loss: 1.4877 - val_y1_output_loss: 0.2815 - val_y2_output_loss: 1.2146 - val_y1_output_root_mean_squared_error: 0.5333 - val_y2_output_root_mean_squared_error: 1.0969
# Epoch 497/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3722 - y1_output_loss: 0.1240 - y2_output_loss: 0.2559 - y1_output_root_mean_squared_error: 0.3525 - y2_output_root_mean_squared_error: 0.4980 - val_loss: 1.0791 - val_y1_output_loss: 0.2607 - val_y2_output_loss: 0.8088 - val_y1_output_root_mean_squared_error: 0.5174 - val_y2_output_root_mean_squared_error: 0.9008
# Epoch 498/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3305 - y1_output_loss: 0.1114 - y2_output_loss: 0.2187 - y1_output_root_mean_squared_error: 0.3317 - y2_output_root_mean_squared_error: 0.4695 - val_loss: 0.7200 - val_y1_output_loss: 0.2625 - val_y2_output_loss: 0.4501 - val_y1_output_root_mean_squared_error: 0.5198 - val_y2_output_root_mean_squared_error: 0.6707
# Epoch 499/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3257 - y1_output_loss: 0.1021 - y2_output_loss: 0.2212 - y1_output_root_mean_squared_error: 0.3211 - y2_output_root_mean_squared_error: 0.4718 - val_loss: 0.7529 - val_y1_output_loss: 0.2114 - val_y2_output_loss: 0.5335 - val_y1_output_root_mean_squared_error: 0.4647 - val_y2_output_root_mean_squared_error: 0.7328
# Epoch 500/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3460 - y1_output_loss: 0.0929 - y2_output_loss: 0.2547 - y1_output_root_mean_squared_error: 0.3042 - y2_output_root_mean_squared_error: 0.5035 - val_loss: 1.3189 - val_y1_output_loss: 0.2785 - val_y2_output_loss: 1.0249 - val_y1_output_root_mean_squared_error: 0.5358 - val_y2_output_root_mean_squared_error: 1.0158

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 42us/sample - loss: 1.3189 - y1_output_loss: 0.2901 - y2_output_loss: 1.0272 - y1_output_root_mean_squared_error: 0.5358 - y2_output_root_mean_squared_error: 1.0158
# Loss = 1.3188623731786555, Y1_loss = 0.29008859395980835, Y1_mse = 0.5357556939125061, Y2_loss = 1.0272144079208374, Y2_mse = 1.01578950881958

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
